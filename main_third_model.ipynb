# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import path, os, random, math
from pathlib import Path

from Source import ThirdModel, accuracy

from sklearn.preprocessing import LabelBinarizer
# Out:
# /Users/nhat/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/nhat/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Define paths:
d = Path().resolve()
data_path = str(d) + "/Data"
train_path = data_path + "/train.csv"
predictions_path = "/output/"
sample_path = data_path + "/sample_submission.csv"
weight_save_path = str(d) + "/weights/model_third.ckpt"
weight_load_path = weight_save_path

# %%
# Prepare data:
df_train = pd.read_csv(data_path + "/emnist-letters-train.csv")
df_test = pd.read_csv(data_path + "/emnist-letters-test.csv")

y_train = df_train.iloc[:, 0].values
y_test = df_test.iloc[:, 0].values

X_train = df_train.iloc[:, 1:].values
X_test = df_test.iloc[:, 1:].values
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
# One-hot encode the y-values:
lb = LabelBinarizer()
lb.fit(y_train)
y_train_enc = lb.transform(y_train)
y_test_enc = lb.transform(y_test)

# %%
# Define hyperparameters:
num_epoch = 15
batch_size = 64




# Define model:
model = ThirdModel(inp_w = 28, inp_h = 28, inp_d = 1)
model.fit(X_train, y_train_enc, num_epoch = num_epoch, batch_size = batch_size, weight_save_path = weight_save_path, plot_losses = True)
# Out:
# Training Characters Classifier for 15 epochs
# Iteration 0: with minibatch training loss = 3.96 and accuracy of 0.047
# Iteration 1: with minibatch training loss = 3.79 and accuracy of 0.031
# Iteration 2: with minibatch training loss = 3.94 and accuracy of 0.031
# Iteration 3: with minibatch training loss = 3.61 and accuracy of 0.094
# Iteration 4: with minibatch training loss = 3.73 and accuracy of 0.047
# Iteration 5: with minibatch training loss = 3.63 and accuracy of 0.047
# Iteration 6: with minibatch training loss = 3.46 and accuracy of 0.094
# Iteration 7: with minibatch training loss = 3.48 and accuracy of 0.078
# Iteration 8: with minibatch training loss = 3.57 and accuracy of 0.047
# Iteration 9: with minibatch training loss = 3.27 and accuracy of 0.16
# Iteration 10: with minibatch training loss = 3.28 and accuracy of 0.16
# Iteration 11: with minibatch training loss = 3.02 and accuracy of 0.17
# Iteration 12: with minibatch training loss = 3.38 and accuracy of 0.11
# Iteration 13: with minibatch training loss = 3.18 and accuracy of 0.14
# Iteration 14: with minibatch training loss = 3.1 and accuracy of 0.16
# Iteration 15: with minibatch training loss = 3.28 and accuracy of 0.14
# Iteration 16: with minibatch training loss = 3.19 and accuracy of 0.16
# Iteration 17: with minibatch training loss = 2.97 and accuracy of 0.22
# Iteration 18: with minibatch training loss = 3.02 and accuracy of 0.17
# Iteration 19: with minibatch training loss = 3.13 and accuracy of 0.17
# Iteration 20: with minibatch training loss = 2.79 and accuracy of 0.2
# Iteration 21: with minibatch training loss = 3.11 and accuracy of 0.11
# Iteration 22: with minibatch training loss = 2.85 and accuracy of 0.19
# Iteration 23: with minibatch training loss = 2.61 and accuracy of 0.31
# Iteration 24: with minibatch training loss = 2.51 and accuracy of 0.36
# Iteration 25: with minibatch training loss = 3.01 and accuracy of 0.25
# Iteration 26: with minibatch training loss = 2.58 and accuracy of 0.31
# Iteration 27: with minibatch training loss = 2.69 and accuracy of 0.23
# Iteration 28: with minibatch training loss = 2.77 and accuracy of 0.19
# Iteration 29: with minibatch training loss = 2.78 and accuracy of 0.25
# Iteration 30: with minibatch training loss = 2.58 and accuracy of 0.27
# Iteration 31: with minibatch training loss = 2.28 and accuracy of 0.39
# Iteration 32: with minibatch training loss = 2.76 and accuracy of 0.2
# Iteration 33: with minibatch training loss = 2.33 and accuracy of 0.42
# Iteration 34: with minibatch training loss = 2.93 and accuracy of 0.17
# Iteration 35: with minibatch training loss = 2.32 and accuracy of 0.38
# Iteration 36: with minibatch training loss = 2.49 and accuracy of 0.31
# Iteration 37: with minibatch training loss = 2.42 and accuracy of 0.3
# Iteration 38: with minibatch training loss = 2.25 and accuracy of 0.42
# Iteration 39: with minibatch training loss = 2.29 and accuracy of 0.38
# Iteration 40: with minibatch training loss = 2.66 and accuracy of 0.23
# Iteration 41: with minibatch training loss = 2.38 and accuracy of 0.39
# Iteration 42: with minibatch training loss = 2.13 and accuracy of 0.39
# Iteration 43: with minibatch training loss = 2.32 and accuracy of 0.36
# Iteration 44: with minibatch training loss = 2.28 and accuracy of 0.38
# Iteration 45: with minibatch training loss = 2.16 and accuracy of 0.44
# Iteration 46: with minibatch training loss = 2.54 and accuracy of 0.27
# Iteration 47: with minibatch training loss = 2.44 and accuracy of 0.34
# Iteration 48: with minibatch training loss = 2.39 and accuracy of 0.34
# Iteration 49: with minibatch training loss = 2.09 and accuracy of 0.39
# Iteration 50: with minibatch training loss = 2.43 and accuracy of 0.3
# Iteration 51: with minibatch training loss = 2.5 and accuracy of 0.3
# Iteration 52: with minibatch training loss = 2.3 and accuracy of 0.44
# Iteration 53: with minibatch training loss = 2.23 and accuracy of 0.41
# Iteration 54: with minibatch training loss = 2.36 and accuracy of 0.36
# Iteration 55: with minibatch training loss = 2.31 and accuracy of 0.34
# Iteration 56: with minibatch training loss = 2.19 and accuracy of 0.38
# Iteration 57: with minibatch training loss = 2.14 and accuracy of 0.39
# Iteration 58: with minibatch training loss = 2.13 and accuracy of 0.41
# Iteration 59: with minibatch training loss = 2.4 and accuracy of 0.42
# Iteration 60: with minibatch training loss = 2 and accuracy of 0.56
# Iteration 61: with minibatch training loss = 2.32 and accuracy of 0.36
# Iteration 62: with minibatch training loss = 2.18 and accuracy of 0.41
# Iteration 63: with minibatch training loss = 2.35 and accuracy of 0.41
# Iteration 64: with minibatch training loss = 2.24 and accuracy of 0.47
# Iteration 65: with minibatch training loss = 2.17 and accuracy of 0.44
# Iteration 66: with minibatch training loss = 1.99 and accuracy of 0.5
# Iteration 67: with minibatch training loss = 2.18 and accuracy of 0.45
# Iteration 68: with minibatch training loss = 1.97 and accuracy of 0.5
# Iteration 69: with minibatch training loss = 2.21 and accuracy of 0.38
# Iteration 70: with minibatch training loss = 1.71 and accuracy of 0.62
# Iteration 71: with minibatch training loss = 2.12 and accuracy of 0.45
# Iteration 72: with minibatch training loss = 2.12 and accuracy of 0.42
# Iteration 73: with minibatch training loss = 2.06 and accuracy of 0.47
# Iteration 74: with minibatch training loss = 2.25 and accuracy of 0.36
# Iteration 75: with minibatch training loss = 2.41 and accuracy of 0.36
# Iteration 76: with minibatch training loss = 2.2 and accuracy of 0.45
# Iteration 77: with minibatch training loss = 2.05 and accuracy of 0.52
# Iteration 78: with minibatch training loss = 2.31 and accuracy of 0.41
# Iteration 79: with minibatch training loss = 1.98 and accuracy of 0.52
# Iteration 80: with minibatch training loss = 1.99 and accuracy of 0.5
# Iteration 81: with minibatch training loss = 1.93 and accuracy of 0.5
# Iteration 82: with minibatch training loss = 1.88 and accuracy of 0.47
# Iteration 83: with minibatch training loss = 2.29 and accuracy of 0.47
# Iteration 84: with minibatch training loss = 2.27 and accuracy of 0.44
# Iteration 85: with minibatch training loss = 2.05 and accuracy of 0.45
# Iteration 86: with minibatch training loss = 2.19 and accuracy of 0.5
# Iteration 87: with minibatch training loss = 2.09 and accuracy of 0.5
# Iteration 88: with minibatch training loss = 2.08 and accuracy of 0.44
# Iteration 89: with minibatch training loss = 2 and accuracy of 0.5
# Iteration 90: with minibatch training loss = 2.01 and accuracy of 0.53
# Iteration 91: with minibatch training loss = 2.01 and accuracy of 0.52
# Iteration 92: with minibatch training loss = 2.13 and accuracy of 0.47
# Iteration 93: with minibatch training loss = 1.81 and accuracy of 0.52
# Iteration 94: with minibatch training loss = 1.87 and accuracy of 0.55
# Iteration 95: with minibatch training loss = 1.79 and accuracy of 0.56
# Iteration 96: with minibatch training loss = 1.88 and accuracy of 0.64
# Iteration 97: with minibatch training loss = 1.88 and accuracy of 0.56
# Iteration 98: with minibatch training loss = 1.94 and accuracy of 0.52
# Iteration 99: with minibatch training loss = 1.87 and accuracy of 0.55
# Iteration 100: with minibatch training loss = 2.08 and accuracy of 0.42
# Iteration 101: with minibatch training loss = 1.97 and accuracy of 0.44
# Iteration 102: with minibatch training loss = 1.84 and accuracy of 0.53
# Iteration 103: with minibatch training loss = 1.86 and accuracy of 0.52
# Iteration 104: with minibatch training loss = 1.99 and accuracy of 0.45
# Iteration 105: with minibatch training loss = 2.11 and accuracy of 0.41
# Iteration 106: with minibatch training loss = 1.89 and accuracy of 0.53
# Iteration 107: with minibatch training loss = 1.82 and accuracy of 0.52
# Iteration 108: with minibatch training loss = 2.31 and accuracy of 0.42
# Iteration 109: with minibatch training loss = 2.08 and accuracy of 0.42
# Iteration 110: with minibatch training loss = 1.63 and accuracy of 0.64
# Iteration 111: with minibatch training loss = 1.95 and accuracy of 0.48
# Iteration 112: with minibatch training loss = 2 and accuracy of 0.53
# Iteration 113: with minibatch training loss = 1.73 and accuracy of 0.56
# Iteration 114: with minibatch training loss = 1.74 and accuracy of 0.56
# Iteration 115: with minibatch training loss = 1.81 and accuracy of 0.56
# Iteration 116: with minibatch training loss = 2.02 and accuracy of 0.44
# Iteration 117: with minibatch training loss = 1.7 and accuracy of 0.55
# Iteration 118: with minibatch training loss = 1.68 and accuracy of 0.61
# Iteration 119: with minibatch training loss = 2.03 and accuracy of 0.48
# Iteration 120: with minibatch training loss = 1.81 and accuracy of 0.52
# Iteration 121: with minibatch training loss = 1.86 and accuracy of 0.56
# Iteration 122: with minibatch training loss = 2.07 and accuracy of 0.42
# Iteration 123: with minibatch training loss = 2.05 and accuracy of 0.48
# Iteration 124: with minibatch training loss = 1.65 and accuracy of 0.62
# Iteration 125: with minibatch training loss = 1.8 and accuracy of 0.55
# Iteration 126: with minibatch training loss = 1.76 and accuracy of 0.56
# Iteration 127: with minibatch training loss = 1.78 and accuracy of 0.55
# Iteration 128: with minibatch training loss = 1.63 and accuracy of 0.66
# Iteration 129: with minibatch training loss = 1.54 and accuracy of 0.66
# Iteration 130: with minibatch training loss = 1.98 and accuracy of 0.42
# Iteration 131: with minibatch training loss = 1.95 and accuracy of 0.48
# Iteration 132: with minibatch training loss = 1.78 and accuracy of 0.62
# Iteration 133: with minibatch training loss = 1.69 and accuracy of 0.67
# Iteration 134: with minibatch training loss = 1.6 and accuracy of 0.59
# Iteration 135: with minibatch training loss = 1.52 and accuracy of 0.67
# Iteration 136: with minibatch training loss = 1.53 and accuracy of 0.69
# Iteration 137: with minibatch training loss = 1.56 and accuracy of 0.56
# Iteration 138: with minibatch training loss = 1.85 and accuracy of 0.58
# Iteration 139: with minibatch training loss = 1.84 and accuracy of 0.58
# Iteration 140: with minibatch training loss = 1.55 and accuracy of 0.66
# Iteration 141: with minibatch training loss = 1.77 and accuracy of 0.61
# Iteration 142: with minibatch training loss = 1.59 and accuracy of 0.62
# Iteration 143: with minibatch training loss = 1.57 and accuracy of 0.66
# Iteration 144: with minibatch training loss = 2.03 and accuracy of 0.47
# Iteration 145: with minibatch training loss = 1.62 and accuracy of 0.59
# Iteration 146: with minibatch training loss = 1.8 and accuracy of 0.59
# Iteration 147: with minibatch training loss = 1.75 and accuracy of 0.56
# Iteration 148: with minibatch training loss = 1.84 and accuracy of 0.56
# Iteration 149: with minibatch training loss = 1.99 and accuracy of 0.48
# Iteration 150: with minibatch training loss = 1.48 and accuracy of 0.7
# Iteration 151: with minibatch training loss = 1.73 and accuracy of 0.59
# Iteration 152: with minibatch training loss = 1.49 and accuracy of 0.64
# Iteration 153: with minibatch training loss = 1.62 and accuracy of 0.62
# Iteration 154: with minibatch training loss = 1.99 and accuracy of 0.5
# Iteration 155: with minibatch training loss = 1.43 and accuracy of 0.64
# Iteration 156: with minibatch training loss = 1.69 and accuracy of 0.58
# Iteration 157: with minibatch training loss = 1.69 and accuracy of 0.61
# Iteration 158: with minibatch training loss = 2.1 and accuracy of 0.44
# Iteration 159: with minibatch training loss = 1.72 and accuracy of 0.56
# Iteration 160: with minibatch training loss = 1.81 and accuracy of 0.53
# Iteration 161: with minibatch training loss = 1.78 and accuracy of 0.59
# Iteration 162: with minibatch training loss = 1.79 and accuracy of 0.61
# Iteration 163: with minibatch training loss = 1.63 and accuracy of 0.59
# Iteration 164: with minibatch training loss = 1.58 and accuracy of 0.69
# Iteration 165: with minibatch training loss = 1.55 and accuracy of 0.59
# Iteration 166: with minibatch training loss = 1.43 and accuracy of 0.66
# Iteration 167: with minibatch training loss = 1.92 and accuracy of 0.53
# Iteration 168: with minibatch training loss = 1.49 and accuracy of 0.66
# Iteration 169: with minibatch training loss = 1.75 and accuracy of 0.56
# Iteration 170: with minibatch training loss = 1.46 and accuracy of 0.62
# Iteration 171: with minibatch training loss = 1.48 and accuracy of 0.66
# Iteration 172: with minibatch training loss = 1.87 and accuracy of 0.53
# Iteration 173: with minibatch training loss = 1.59 and accuracy of 0.58
# Iteration 174: with minibatch training loss = 1.78 and accuracy of 0.47
# Iteration 175: with minibatch training loss = 1.81 and accuracy of 0.59
# Iteration 176: with minibatch training loss = 1.59 and accuracy of 0.66
# Iteration 177: with minibatch training loss = 1.44 and accuracy of 0.69
# Iteration 178: with minibatch training loss = 1.73 and accuracy of 0.47
# Iteration 179: with minibatch training loss = 1.5 and accuracy of 0.69
# Iteration 180: with minibatch training loss = 1.75 and accuracy of 0.61
# Iteration 181: with minibatch training loss = 1.52 and accuracy of 0.61
# Iteration 182: with minibatch training loss = 1.9 and accuracy of 0.53
# Iteration 183: with minibatch training loss = 1.59 and accuracy of 0.59
# Iteration 184: with minibatch training loss = 1.61 and accuracy of 0.61
# Iteration 185: with minibatch training loss = 1.61 and accuracy of 0.66
# Iteration 186: with minibatch training loss = 1.88 and accuracy of 0.55
# Iteration 187: with minibatch training loss = 1.7 and accuracy of 0.58
# Iteration 188: with minibatch training loss = 1.97 and accuracy of 0.48
# Iteration 189: with minibatch training loss = 1.68 and accuracy of 0.56
# Iteration 190: with minibatch training loss = 1.66 and accuracy of 0.59
# Iteration 191: with minibatch training loss = 1.93 and accuracy of 0.48
# Iteration 192: with minibatch training loss = 1.55 and accuracy of 0.59
# Iteration 193: with minibatch training loss = 1.62 and accuracy of 0.55
# Iteration 194: with minibatch training loss = 1.53 and accuracy of 0.61
# Iteration 195: with minibatch training loss = 1.96 and accuracy of 0.45
# Iteration 196: with minibatch training loss = 1.65 and accuracy of 0.66
# Iteration 197: with minibatch training loss = 1.35 and accuracy of 0.72
# Iteration 198: with minibatch training loss = 1.69 and accuracy of 0.56
# Iteration 199: with minibatch training loss = 1.77 and accuracy of 0.56
# Iteration 200: with minibatch training loss = 1.58 and accuracy of 0.62
# Iteration 201: with minibatch training loss = 1.44 and accuracy of 0.67
# Iteration 202: with minibatch training loss = 1.51 and accuracy of 0.66
# Iteration 203: with minibatch training loss = 1.91 and accuracy of 0.47
# Iteration 204: with minibatch training loss = 1.48 and accuracy of 0.61
# Iteration 205: with minibatch training loss = 1.6 and accuracy of 0.62
# Iteration 206: with minibatch training loss = 1.53 and accuracy of 0.67
# Iteration 207: with minibatch training loss = 1.69 and accuracy of 0.64
# Iteration 208: with minibatch training loss = 1.52 and accuracy of 0.67
# Iteration 209: with minibatch training loss = 1.84 and accuracy of 0.52
# Iteration 210: with minibatch training loss = 1.57 and accuracy of 0.59
# Iteration 211: with minibatch training loss = 1.45 and accuracy of 0.69
# Iteration 212: with minibatch training loss = 1.51 and accuracy of 0.66
# Iteration 213: with minibatch training loss = 1.68 and accuracy of 0.59
# Iteration 214: with minibatch training loss = 1.6 and accuracy of 0.62
# Iteration 215: with minibatch training loss = 1.67 and accuracy of 0.56
# Iteration 216: with minibatch training loss = 1.53 and accuracy of 0.66
# Iteration 217: with minibatch training loss = 1.77 and accuracy of 0.5
# Iteration 218: with minibatch training loss = 1.82 and accuracy of 0.52
# Iteration 219: with minibatch training loss = 1.54 and accuracy of 0.67
# Iteration 220: with minibatch training loss = 1.4 and accuracy of 0.66
# Iteration 221: with minibatch training loss = 1.78 and accuracy of 0.52
# Iteration 222: with minibatch training loss = 1.47 and accuracy of 0.62
# Iteration 223: with minibatch training loss = 1.16 and accuracy of 0.78
# Iteration 224: with minibatch training loss = 1.54 and accuracy of 0.61
# Iteration 225: with minibatch training loss = 1.72 and accuracy of 0.55
# Iteration 226: with minibatch training loss = 1.69 and accuracy of 0.61
# Iteration 227: with minibatch training loss = 1.31 and accuracy of 0.7
# Iteration 228: with minibatch training loss = 1.56 and accuracy of 0.64
# Iteration 229: with minibatch training loss = 1.23 and accuracy of 0.72
# Iteration 230: with minibatch training loss = 1.52 and accuracy of 0.59
# Iteration 231: with minibatch training loss = 1.4 and accuracy of 0.66
# Iteration 232: with minibatch training loss = 1.42 and accuracy of 0.69
# Iteration 233: with minibatch training loss = 1.43 and accuracy of 0.66
# Iteration 234: with minibatch training loss = 1.36 and accuracy of 0.62
# Iteration 235: with minibatch training loss = 1.51 and accuracy of 0.66
# Iteration 236: with minibatch training loss = 1.45 and accuracy of 0.67
# Iteration 237: with minibatch training loss = 1.5 and accuracy of 0.62
# Iteration 238: with minibatch training loss = 1.33 and accuracy of 0.73
# Iteration 239: with minibatch training loss = 1.63 and accuracy of 0.58
# Iteration 240: with minibatch training loss = 1.51 and accuracy of 0.62
# Iteration 241: with minibatch training loss = 1.6 and accuracy of 0.64
# Iteration 242: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 243: with minibatch training loss = 1.56 and accuracy of 0.64
# Iteration 244: with minibatch training loss = 1.65 and accuracy of 0.61
# Iteration 245: with minibatch training loss = 1.57 and accuracy of 0.61
# Iteration 246: with minibatch training loss = 1.68 and accuracy of 0.59
# Iteration 247: with minibatch training loss = 1.54 and accuracy of 0.64
# Iteration 248: with minibatch training loss = 1.51 and accuracy of 0.56
# Iteration 249: with minibatch training loss = 1.68 and accuracy of 0.56
# Iteration 250: with minibatch training loss = 1.64 and accuracy of 0.59
# Iteration 251: with minibatch training loss = 1.79 and accuracy of 0.53
# Iteration 252: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 253: with minibatch training loss = 1.68 and accuracy of 0.52
# Iteration 254: with minibatch training loss = 1.47 and accuracy of 0.67
# Iteration 255: with minibatch training loss = 1.43 and accuracy of 0.67
# Iteration 256: with minibatch training loss = 1.55 and accuracy of 0.64
# Iteration 257: with minibatch training loss = 1.42 and accuracy of 0.66
# Iteration 258: with minibatch training loss = 1.75 and accuracy of 0.56
# Iteration 259: with minibatch training loss = 1.5 and accuracy of 0.67
# Iteration 260: with minibatch training loss = 1.88 and accuracy of 0.55
# Iteration 261: with minibatch training loss = 1.48 and accuracy of 0.67
# Iteration 262: with minibatch training loss = 1.29 and accuracy of 0.7
# Iteration 263: with minibatch training loss = 1.35 and accuracy of 0.7
# Iteration 264: with minibatch training loss = 1.44 and accuracy of 0.64
# Iteration 265: with minibatch training loss = 1.36 and accuracy of 0.67
# Iteration 266: with minibatch training loss = 1.59 and accuracy of 0.56
# Iteration 267: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 268: with minibatch training loss = 1.69 and accuracy of 0.56
# Iteration 269: with minibatch training loss = 1.38 and accuracy of 0.64
# Iteration 270: with minibatch training loss = 1.68 and accuracy of 0.53
# Iteration 271: with minibatch training loss = 1.55 and accuracy of 0.58
# Iteration 272: with minibatch training loss = 1.65 and accuracy of 0.61
# Iteration 273: with minibatch training loss = 1.23 and accuracy of 0.72
# Iteration 274: with minibatch training loss = 1.66 and accuracy of 0.59
# Iteration 275: with minibatch training loss = 1.37 and accuracy of 0.72
# Iteration 276: with minibatch training loss = 1.7 and accuracy of 0.58
# Iteration 277: with minibatch training loss = 1.48 and accuracy of 0.64
# Iteration 278: with minibatch training loss = 1.57 and accuracy of 0.66
# Iteration 279: with minibatch training loss = 1.48 and accuracy of 0.61
# Iteration 280: with minibatch training loss = 1.39 and accuracy of 0.69
# Iteration 281: with minibatch training loss = 1.43 and accuracy of 0.62
# Iteration 282: with minibatch training loss = 1.45 and accuracy of 0.69
# Iteration 283: with minibatch training loss = 1.43 and accuracy of 0.66
# Iteration 284: with minibatch training loss = 1.48 and accuracy of 0.64
# Iteration 285: with minibatch training loss = 1.32 and accuracy of 0.7
# Iteration 286: with minibatch training loss = 1.39 and accuracy of 0.61
# Iteration 287: with minibatch training loss = 1.39 and accuracy of 0.66
# Iteration 288: with minibatch training loss = 1.51 and accuracy of 0.64
# Iteration 289: with minibatch training loss = 1.29 and accuracy of 0.69
# Iteration 290: with minibatch training loss = 1.59 and accuracy of 0.58
# Iteration 291: with minibatch training loss = 1.64 and accuracy of 0.64
# Iteration 292: with minibatch training loss = 1.56 and accuracy of 0.61
# Iteration 293: with minibatch training loss = 1.59 and accuracy of 0.61
# Iteration 294: with minibatch training loss = 1.66 and accuracy of 0.62
# Iteration 295: with minibatch training loss = 1.59 and accuracy of 0.62
# Iteration 296: with minibatch training loss = 1.65 and accuracy of 0.58
# Iteration 297: with minibatch training loss = 1.56 and accuracy of 0.66
# Iteration 298: with minibatch training loss = 1.57 and accuracy of 0.59
# Iteration 299: with minibatch training loss = 1.45 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 1.57 and accuracy of 0.62
# Iteration 301: with minibatch training loss = 1.55 and accuracy of 0.62
# Iteration 302: with minibatch training loss = 1.61 and accuracy of 0.59
# Iteration 303: with minibatch training loss = 1.39 and accuracy of 0.64
# Iteration 304: with minibatch training loss = 1.4 and accuracy of 0.64
# Iteration 305: with minibatch training loss = 1.22 and accuracy of 0.78
# Iteration 306: with minibatch training loss = 1.4 and accuracy of 0.64
# Iteration 307: with minibatch training loss = 1.4 and accuracy of 0.61
# Iteration 308: with minibatch training loss = 1.37 and accuracy of 0.67
# Iteration 309: with minibatch training loss = 1.48 and accuracy of 0.62
# Iteration 310: with minibatch training loss = 1.44 and accuracy of 0.69
# Iteration 311: with minibatch training loss = 1.42 and accuracy of 0.64
# Iteration 312: with minibatch training loss = 1.47 and accuracy of 0.62
# Iteration 313: with minibatch training loss = 1.39 and accuracy of 0.69
# Iteration 314: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 315: with minibatch training loss = 1.35 and accuracy of 0.66
# Iteration 316: with minibatch training loss = 1.35 and accuracy of 0.66
# Iteration 317: with minibatch training loss = 1.64 and accuracy of 0.59
# Iteration 318: with minibatch training loss = 1.36 and accuracy of 0.7
# Iteration 319: with minibatch training loss = 1.39 and accuracy of 0.62
# Iteration 320: with minibatch training loss = 1.58 and accuracy of 0.59
# Iteration 321: with minibatch training loss = 1.7 and accuracy of 0.52
# Iteration 322: with minibatch training loss = 1.23 and accuracy of 0.66
# Iteration 323: with minibatch training loss = 1.54 and accuracy of 0.61
# Iteration 324: with minibatch training loss = 1.4 and accuracy of 0.62
# Iteration 325: with minibatch training loss = 1.45 and accuracy of 0.69
# Iteration 326: with minibatch training loss = 1.2 and accuracy of 0.73
# Iteration 327: with minibatch training loss = 1.36 and accuracy of 0.7
# Iteration 328: with minibatch training loss = 1.53 and accuracy of 0.62
# Iteration 329: with minibatch training loss = 1.48 and accuracy of 0.66
# Iteration 330: with minibatch training loss = 1.1 and accuracy of 0.72
# Iteration 331: with minibatch training loss = 1.37 and accuracy of 0.69
# Iteration 332: with minibatch training loss = 1.45 and accuracy of 0.7
# Iteration 333: with minibatch training loss = 1.21 and accuracy of 0.73
# Iteration 334: with minibatch training loss = 1.48 and accuracy of 0.66
# Iteration 335: with minibatch training loss = 1.36 and accuracy of 0.67
# Iteration 336: with minibatch training loss = 1.35 and accuracy of 0.69
# Iteration 337: with minibatch training loss = 1.44 and accuracy of 0.67
# Iteration 338: with minibatch training loss = 1.74 and accuracy of 0.58
# Iteration 339: with minibatch training loss = 1.34 and accuracy of 0.7
# Iteration 340: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 341: with minibatch training loss = 1.32 and accuracy of 0.7
# Iteration 342: with minibatch training loss = 1.72 and accuracy of 0.59
# Iteration 343: with minibatch training loss = 1.36 and accuracy of 0.72
# Iteration 344: with minibatch training loss = 1.5 and accuracy of 0.62
# Iteration 345: with minibatch training loss = 1.5 and accuracy of 0.61
# Iteration 346: with minibatch training loss = 1.19 and accuracy of 0.75
# Iteration 347: with minibatch training loss = 1.42 and accuracy of 0.67
# Iteration 348: with minibatch training loss = 0.908 and accuracy of 0.86
# Iteration 349: with minibatch training loss = 1.35 and accuracy of 0.69
# Iteration 350: with minibatch training loss = 1.6 and accuracy of 0.62
# Iteration 351: with minibatch training loss = 1.43 and accuracy of 0.67
# Iteration 352: with minibatch training loss = 1.54 and accuracy of 0.61
# Iteration 353: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 354: with minibatch training loss = 1.42 and accuracy of 0.66
# Iteration 355: with minibatch training loss = 1.57 and accuracy of 0.58
# Iteration 356: with minibatch training loss = 1.56 and accuracy of 0.62
# Iteration 357: with minibatch training loss = 1.64 and accuracy of 0.52
# Iteration 358: with minibatch training loss = 1.34 and accuracy of 0.67
# Iteration 359: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 360: with minibatch training loss = 1.6 and accuracy of 0.58
# Iteration 361: with minibatch training loss = 1.33 and accuracy of 0.69
# Iteration 362: with minibatch training loss = 1.46 and accuracy of 0.59
# Iteration 363: with minibatch training loss = 1.22 and accuracy of 0.67
# Iteration 364: with minibatch training loss = 1.36 and accuracy of 0.64
# Iteration 365: with minibatch training loss = 1.5 and accuracy of 0.62
# Iteration 366: with minibatch training loss = 1.72 and accuracy of 0.61
# Iteration 367: with minibatch training loss = 1.35 and accuracy of 0.67
# Iteration 368: with minibatch training loss = 1.33 and accuracy of 0.72
# Iteration 369: with minibatch training loss = 1.41 and accuracy of 0.69
# Iteration 370: with minibatch training loss = 1.3 and accuracy of 0.7
# Iteration 371: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 372: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 373: with minibatch training loss = 1.52 and accuracy of 0.64
# Iteration 374: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 375: with minibatch training loss = 1.16 and accuracy of 0.72
# Iteration 376: with minibatch training loss = 1.47 and accuracy of 0.66
# Iteration 377: with minibatch training loss = 1.32 and accuracy of 0.7
# Iteration 378: with minibatch training loss = 1.19 and accuracy of 0.69
# Iteration 379: with minibatch training loss = 1.25 and accuracy of 0.67
# Iteration 380: with minibatch training loss = 1.23 and accuracy of 0.72
# Iteration 381: with minibatch training loss = 1.49 and accuracy of 0.66
# Iteration 382: with minibatch training loss = 1.18 and accuracy of 0.73
# Iteration 383: with minibatch training loss = 1.42 and accuracy of 0.67
# Iteration 384: with minibatch training loss = 1.49 and accuracy of 0.7
# Iteration 385: with minibatch training loss = 1.26 and accuracy of 0.67
# Iteration 386: with minibatch training loss = 1.57 and accuracy of 0.58
# Iteration 387: with minibatch training loss = 1.46 and accuracy of 0.62
# Iteration 388: with minibatch training loss = 1.47 and accuracy of 0.64
# Iteration 389: with minibatch training loss = 1.62 and accuracy of 0.55
# Iteration 390: with minibatch training loss = 1.5 and accuracy of 0.62
# Iteration 391: with minibatch training loss = 1.5 and accuracy of 0.66
# Iteration 392: with minibatch training loss = 1.31 and accuracy of 0.67
# Iteration 393: with minibatch training loss = 1.39 and accuracy of 0.66
# Iteration 394: with minibatch training loss = 1.35 and accuracy of 0.69
# Iteration 395: with minibatch training loss = 1.74 and accuracy of 0.56
# Iteration 396: with minibatch training loss = 1.37 and accuracy of 0.62
# Iteration 397: with minibatch training loss = 1.32 and accuracy of 0.64
# Iteration 398: with minibatch training loss = 1.7 and accuracy of 0.55
# Iteration 399: with minibatch training loss = 1.27 and accuracy of 0.7
# Iteration 400: with minibatch training loss = 1.32 and accuracy of 0.66
# Iteration 401: with minibatch training loss = 1.31 and accuracy of 0.67
# Iteration 402: with minibatch training loss = 1.38 and accuracy of 0.69
# Iteration 403: with minibatch training loss = 1.69 and accuracy of 0.55
# Iteration 404: with minibatch training loss = 1.33 and accuracy of 0.66
# Iteration 405: with minibatch training loss = 1.48 and accuracy of 0.64
# Iteration 406: with minibatch training loss = 1.61 and accuracy of 0.58
# Iteration 407: with minibatch training loss = 1.17 and accuracy of 0.72
# Iteration 408: with minibatch training loss = 0.998 and accuracy of 0.73
# Iteration 409: with minibatch training loss = 1.21 and accuracy of 0.72
# Iteration 410: with minibatch training loss = 1.6 and accuracy of 0.59
# Iteration 411: with minibatch training loss = 1.12 and accuracy of 0.73
# Iteration 412: with minibatch training loss = 1.51 and accuracy of 0.64
# Iteration 413: with minibatch training loss = 1.52 and accuracy of 0.61
# Iteration 414: with minibatch training loss = 1.45 and accuracy of 0.62
# Iteration 415: with minibatch training loss = 1.45 and accuracy of 0.66
# Iteration 416: with minibatch training loss = 1.37 and accuracy of 0.64
# Iteration 417: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 418: with minibatch training loss = 1.26 and accuracy of 0.69
# Iteration 419: with minibatch training loss = 1.48 and accuracy of 0.7
# Iteration 420: with minibatch training loss = 1.41 and accuracy of 0.62
# Iteration 421: with minibatch training loss = 1.25 and accuracy of 0.75
# Iteration 422: with minibatch training loss = 1.49 and accuracy of 0.64
# Iteration 423: with minibatch training loss = 1.65 and accuracy of 0.59
# Iteration 424: with minibatch training loss = 1.39 and accuracy of 0.69
# Iteration 425: with minibatch training loss = 1.33 and accuracy of 0.7
# Iteration 426: with minibatch training loss = 1.15 and accuracy of 0.75
# Iteration 427: with minibatch training loss = 1.39 and accuracy of 0.67
# Iteration 428: with minibatch training loss = 1.42 and accuracy of 0.61
# Iteration 429: with minibatch training loss = 1.3 and accuracy of 0.69
# Iteration 430: with minibatch training loss = 1.31 and accuracy of 0.67
# Iteration 431: with minibatch training loss = 1.05 and accuracy of 0.73
# Iteration 432: with minibatch training loss = 1.36 and accuracy of 0.67
# Iteration 433: with minibatch training loss = 1.3 and accuracy of 0.7
# Iteration 434: with minibatch training loss = 1.45 and accuracy of 0.61
# Iteration 435: with minibatch training loss = 1.57 and accuracy of 0.62
# Iteration 436: with minibatch training loss = 1.62 and accuracy of 0.58
# Iteration 437: with minibatch training loss = 1.78 and accuracy of 0.56
# Iteration 438: with minibatch training loss = 1.39 and accuracy of 0.7
# Iteration 439: with minibatch training loss = 1.3 and accuracy of 0.61
# Iteration 440: with minibatch training loss = 1.35 and accuracy of 0.67
# Iteration 441: with minibatch training loss = 1.32 and accuracy of 0.66
# Iteration 442: with minibatch training loss = 1.35 and accuracy of 0.66
# Iteration 443: with minibatch training loss = 1.45 and accuracy of 0.66
# Iteration 444: with minibatch training loss = 1.66 and accuracy of 0.53
# Iteration 445: with minibatch training loss = 1.08 and accuracy of 0.73
# Iteration 446: with minibatch training loss = 1.59 and accuracy of 0.58
# Iteration 447: with minibatch training loss = 1.33 and accuracy of 0.7
# Iteration 448: with minibatch training loss = 1.12 and accuracy of 0.75
# Iteration 449: with minibatch training loss = 1.21 and accuracy of 0.73
# Iteration 450: with minibatch training loss = 1.41 and accuracy of 0.61
# Iteration 451: with minibatch training loss = 1.1 and accuracy of 0.72
# Iteration 452: with minibatch training loss = 1.26 and accuracy of 0.67
# Iteration 453: with minibatch training loss = 1.7 and accuracy of 0.53
# Iteration 454: with minibatch training loss = 1.36 and accuracy of 0.7
# Iteration 455: with minibatch training loss = 1.49 and accuracy of 0.53
# Iteration 456: with minibatch training loss = 1.29 and accuracy of 0.69
# Iteration 457: with minibatch training loss = 1.05 and accuracy of 0.78
# Iteration 458: with minibatch training loss = 0.957 and accuracy of 0.8
# Iteration 459: with minibatch training loss = 1.29 and accuracy of 0.72
# Iteration 460: with minibatch training loss = 1.45 and accuracy of 0.62
# Iteration 461: with minibatch training loss = 1.18 and accuracy of 0.72
# Iteration 462: with minibatch training loss = 1.35 and accuracy of 0.69
# Iteration 463: with minibatch training loss = 1.82 and accuracy of 0.56
# Iteration 464: with minibatch training loss = 1.53 and accuracy of 0.66
# Iteration 465: with minibatch training loss = 1.23 and accuracy of 0.75
# Iteration 466: with minibatch training loss = 1.33 and accuracy of 0.66
# Iteration 467: with minibatch training loss = 1.27 and accuracy of 0.69
# Iteration 468: with minibatch training loss = 1.34 and accuracy of 0.66
# Iteration 469: with minibatch training loss = 0.945 and accuracy of 0.83
# Iteration 470: with minibatch training loss = 1.41 and accuracy of 0.64
# Iteration 471: with minibatch training loss = 1.18 and accuracy of 0.69
# Iteration 472: with minibatch training loss = 1.43 and accuracy of 0.69
# Iteration 473: with minibatch training loss = 1.15 and accuracy of 0.75
# Iteration 474: with minibatch training loss = 1.05 and accuracy of 0.75
# Iteration 475: with minibatch training loss = 1.18 and accuracy of 0.73
# Iteration 476: with minibatch training loss = 1.58 and accuracy of 0.61
# Iteration 477: with minibatch training loss = 1.15 and accuracy of 0.73
# Iteration 478: with minibatch training loss = 1.38 and accuracy of 0.69
# Iteration 479: with minibatch training loss = 1.06 and accuracy of 0.78
# Iteration 480: with minibatch training loss = 1.25 and accuracy of 0.7
# Iteration 481: with minibatch training loss = 1.53 and accuracy of 0.61
# Iteration 482: with minibatch training loss = 1.61 and accuracy of 0.61
# Iteration 483: with minibatch training loss = 1.34 and accuracy of 0.67
# Iteration 484: with minibatch training loss = 1.47 and accuracy of 0.64
# Iteration 485: with minibatch training loss = 1.02 and accuracy of 0.81
# Iteration 486: with minibatch training loss = 1.67 and accuracy of 0.55
# Iteration 487: with minibatch training loss = 1.4 and accuracy of 0.64
# Iteration 488: with minibatch training loss = 1.35 and accuracy of 0.69
# Iteration 489: with minibatch training loss = 1.33 and accuracy of 0.64
# Iteration 490: with minibatch training loss = 1.57 and accuracy of 0.59
# Iteration 491: with minibatch training loss = 1.3 and accuracy of 0.69
# Iteration 492: with minibatch training loss = 1.4 and accuracy of 0.66
# Iteration 493: with minibatch training loss = 1.42 and accuracy of 0.62
# Iteration 494: with minibatch training loss = 1.28 and accuracy of 0.66
# Iteration 495: with minibatch training loss = 1.51 and accuracy of 0.59
# Iteration 496: with minibatch training loss = 1.49 and accuracy of 0.66
# Iteration 497: with minibatch training loss = 1.38 and accuracy of 0.64
# Iteration 498: with minibatch training loss = 1.26 and accuracy of 0.69
# Iteration 499: with minibatch training loss = 1.3 and accuracy of 0.67
# Iteration 500: with minibatch training loss = 1.18 and accuracy of 0.69
# Iteration 501: with minibatch training loss = 1.27 and accuracy of 0.7
# Iteration 502: with minibatch training loss = 1.54 and accuracy of 0.61
# Iteration 503: with minibatch training loss = 1.03 and accuracy of 0.78
# Iteration 504: with minibatch training loss = 1.19 and accuracy of 0.75
# Iteration 505: with minibatch training loss = 1.21 and accuracy of 0.67
# Iteration 506: with minibatch training loss = 1.2 and accuracy of 0.77
# Iteration 507: with minibatch training loss = 1.42 and accuracy of 0.62
# Iteration 508: with minibatch training loss = 1.21 and accuracy of 0.69
# Iteration 509: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 510: with minibatch training loss = 1.47 and accuracy of 0.67
# Iteration 511: with minibatch training loss = 1.05 and accuracy of 0.8
# Iteration 512: with minibatch training loss = 1.4 and accuracy of 0.66
# Iteration 513: with minibatch training loss = 1.46 and accuracy of 0.59
# Iteration 514: with minibatch training loss = 1.53 and accuracy of 0.56
# Iteration 515: with minibatch training loss = 1.42 and accuracy of 0.66
# Iteration 516: with minibatch training loss = 1.36 and accuracy of 0.69
# Iteration 517: with minibatch training loss = 1.32 and accuracy of 0.66
# Iteration 518: with minibatch training loss = 1.55 and accuracy of 0.62
# Iteration 519: with minibatch training loss = 1.24 and accuracy of 0.66
# Iteration 520: with minibatch training loss = 1.05 and accuracy of 0.83
# Iteration 521: with minibatch training loss = 1.28 and accuracy of 0.7
# Iteration 522: with minibatch training loss = 1.12 and accuracy of 0.77
# Iteration 523: with minibatch training loss = 1.11 and accuracy of 0.75
# Iteration 524: with minibatch training loss = 1.28 and accuracy of 0.69
# Iteration 525: with minibatch training loss = 1.32 and accuracy of 0.7
# Iteration 526: with minibatch training loss = 1.02 and accuracy of 0.81
# Iteration 527: with minibatch training loss = 1.58 and accuracy of 0.61
# Iteration 528: with minibatch training loss = 1.36 and accuracy of 0.66
# Iteration 529: with minibatch training loss = 1.43 and accuracy of 0.62
# Iteration 530: with minibatch training loss = 1.17 and accuracy of 0.77
# Iteration 531: with minibatch training loss = 1.54 and accuracy of 0.64
# Iteration 532: with minibatch training loss = 1.54 and accuracy of 0.59
# Iteration 533: with minibatch training loss = 1.06 and accuracy of 0.75
# Iteration 534: with minibatch training loss = 1.27 and accuracy of 0.72
# Iteration 535: with minibatch training loss = 1.56 and accuracy of 0.61
# Iteration 536: with minibatch training loss = 1.53 and accuracy of 0.64
# Iteration 537: with minibatch training loss = 1.42 and accuracy of 0.67
# Iteration 538: with minibatch training loss = 1.36 and accuracy of 0.72
# Iteration 539: with minibatch training loss = 1.42 and accuracy of 0.61
# Iteration 540: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 541: with minibatch training loss = 1.23 and accuracy of 0.7
# Iteration 542: with minibatch training loss = 1.14 and accuracy of 0.73
# Iteration 543: with minibatch training loss = 1.4 and accuracy of 0.66
# Iteration 544: with minibatch training loss = 1.34 and accuracy of 0.67
# Iteration 545: with minibatch training loss = 1.11 and accuracy of 0.75
# Iteration 546: with minibatch training loss = 1.13 and accuracy of 0.7
# Iteration 547: with minibatch training loss = 1.32 and accuracy of 0.69
# Iteration 548: with minibatch training loss = 1.08 and accuracy of 0.77
# Iteration 549: with minibatch training loss = 1.42 and accuracy of 0.66
# Iteration 550: with minibatch training loss = 1.49 and accuracy of 0.58
# Iteration 551: with minibatch training loss = 1.2 and accuracy of 0.66
# Iteration 552: with minibatch training loss = 1.47 and accuracy of 0.62
# Iteration 553: with minibatch training loss = 1.37 and accuracy of 0.7
# Iteration 554: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 555: with minibatch training loss = 1.11 and accuracy of 0.73
# Iteration 556: with minibatch training loss = 1.37 and accuracy of 0.67
# Iteration 557: with minibatch training loss = 1.2 and accuracy of 0.73
# Iteration 558: with minibatch training loss = 0.965 and accuracy of 0.78
# Iteration 559: with minibatch training loss = 1.16 and accuracy of 0.77
# Iteration 560: with minibatch training loss = 1.16 and accuracy of 0.75
# Iteration 561: with minibatch training loss = 1.15 and accuracy of 0.77
# Iteration 562: with minibatch training loss = 1.21 and accuracy of 0.72
# Iteration 563: with minibatch training loss = 1.21 and accuracy of 0.72
# Iteration 564: with minibatch training loss = 1.23 and accuracy of 0.69
# Iteration 565: with minibatch training loss = 1.38 and accuracy of 0.64
# Iteration 566: with minibatch training loss = 1.41 and accuracy of 0.66
# Iteration 567: with minibatch training loss = 1.05 and accuracy of 0.77
# Iteration 568: with minibatch training loss = 1.35 and accuracy of 0.62
# Iteration 569: with minibatch training loss = 1.33 and accuracy of 0.64
# Iteration 570: with minibatch training loss = 1.22 and accuracy of 0.69
# Iteration 571: with minibatch training loss = 1.71 and accuracy of 0.53
# Iteration 572: with minibatch training loss = 1.24 and accuracy of 0.69
# Iteration 573: with minibatch training loss = 1.28 and accuracy of 0.66
# Iteration 574: with minibatch training loss = 1.47 and accuracy of 0.59
# Iteration 575: with minibatch training loss = 1.2 and accuracy of 0.75
# Iteration 576: with minibatch training loss = 1.32 and accuracy of 0.73
# Iteration 577: with minibatch training loss = 1.17 and accuracy of 0.7
# Iteration 578: with minibatch training loss = 1.22 and accuracy of 0.73
# Iteration 579: with minibatch training loss = 1.52 and accuracy of 0.56
# Iteration 580: with minibatch training loss = 1.24 and accuracy of 0.69
# Iteration 581: with minibatch training loss = 1.24 and accuracy of 0.7
# Iteration 582: with minibatch training loss = 1.18 and accuracy of 0.7
# Iteration 583: with minibatch training loss = 1.16 and accuracy of 0.7
# Iteration 584: with minibatch training loss = 1.59 and accuracy of 0.59
# Iteration 585: with minibatch training loss = 1.18 and accuracy of 0.66
# Iteration 586: with minibatch training loss = 1.2 and accuracy of 0.72
# Iteration 587: with minibatch training loss = 1.19 and accuracy of 0.69
# Iteration 588: with minibatch training loss = 1.32 and accuracy of 0.66
# Iteration 589: with minibatch training loss = 1.49 and accuracy of 0.66
# Iteration 590: with minibatch training loss = 1.49 and accuracy of 0.59
# Iteration 591: with minibatch training loss = 0.944 and accuracy of 0.8
# Iteration 592: with minibatch training loss = 1.22 and accuracy of 0.67
# Iteration 593: with minibatch training loss = 1.28 and accuracy of 0.67
# Iteration 594: with minibatch training loss = 1.29 and accuracy of 0.69
# Iteration 595: with minibatch training loss = 1.67 and accuracy of 0.56
# Iteration 596: with minibatch training loss = 1.4 and accuracy of 0.64
# Iteration 597: with minibatch training loss = 1.19 and accuracy of 0.73
# Iteration 598: with minibatch training loss = 1.25 and accuracy of 0.66
# Iteration 599: with minibatch training loss = 1.18 and accuracy of 0.7
# Iteration 600: with minibatch training loss = 1.15 and accuracy of 0.72
# Iteration 601: with minibatch training loss = 1.31 and accuracy of 0.67
# Iteration 602: with minibatch training loss = 1.3 and accuracy of 0.69
# Iteration 603: with minibatch training loss = 1.36 and accuracy of 0.67
# Iteration 604: with minibatch training loss = 1.14 and accuracy of 0.69
# Iteration 605: with minibatch training loss = 1.43 and accuracy of 0.59
# Iteration 606: with minibatch training loss = 1.28 and accuracy of 0.72
# Iteration 607: with minibatch training loss = 0.946 and accuracy of 0.83
# Iteration 608: with minibatch training loss = 1.13 and accuracy of 0.8
# Iteration 609: with minibatch training loss = 1.23 and accuracy of 0.72
# Iteration 610: with minibatch training loss = 1.06 and accuracy of 0.73
# Iteration 611: with minibatch training loss = 1.46 and accuracy of 0.64
# Iteration 612: with minibatch training loss = 1.56 and accuracy of 0.5
# Iteration 613: with minibatch training loss = 1.53 and accuracy of 0.56
# Iteration 614: with minibatch training loss = 1.26 and accuracy of 0.69
# Iteration 615: with minibatch training loss = 1.41 and accuracy of 0.64
# Iteration 616: with minibatch training loss = 1.26 and accuracy of 0.7
# Iteration 617: with minibatch training loss = 1.24 and accuracy of 0.69
# Iteration 618: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 619: with minibatch training loss = 1.11 and accuracy of 0.73
# Iteration 620: with minibatch training loss = 1.23 and accuracy of 0.69
# Iteration 621: with minibatch training loss = 1.18 and accuracy of 0.7
# Iteration 622: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 623: with minibatch training loss = 1.32 and accuracy of 0.69
# Iteration 624: with minibatch training loss = 1.13 and accuracy of 0.72
# Iteration 625: with minibatch training loss = 1.3 and accuracy of 0.69
# Iteration 626: with minibatch training loss = 1.13 and accuracy of 0.7
# Iteration 627: with minibatch training loss = 1.37 and accuracy of 0.66
# Iteration 628: with minibatch training loss = 1.13 and accuracy of 0.69
# Iteration 629: with minibatch training loss = 1.14 and accuracy of 0.75
# Iteration 630: with minibatch training loss = 1.55 and accuracy of 0.62
# Iteration 631: with minibatch training loss = 1.06 and accuracy of 0.78
# Iteration 632: with minibatch training loss = 1.19 and accuracy of 0.7
# Iteration 633: with minibatch training loss = 1.18 and accuracy of 0.7
# Iteration 634: with minibatch training loss = 1.43 and accuracy of 0.66
# Iteration 635: with minibatch training loss = 1.16 and accuracy of 0.67
# Iteration 636: with minibatch training loss = 1.37 and accuracy of 0.64
# Iteration 637: with minibatch training loss = 1.43 and accuracy of 0.7
# Iteration 638: with minibatch training loss = 1.37 and accuracy of 0.62
# Iteration 639: with minibatch training loss = 1.39 and accuracy of 0.64
# Iteration 640: with minibatch training loss = 1.51 and accuracy of 0.62
# Iteration 641: with minibatch training loss = 1.21 and accuracy of 0.75
# Iteration 642: with minibatch training loss = 1.35 and accuracy of 0.66
# Iteration 643: with minibatch training loss = 1.11 and accuracy of 0.75
# Iteration 644: with minibatch training loss = 1.67 and accuracy of 0.53
# Iteration 645: with minibatch training loss = 1.21 and accuracy of 0.7
# Iteration 646: with minibatch training loss = 1.37 and accuracy of 0.64
# Iteration 647: with minibatch training loss = 1.38 and accuracy of 0.66
# Iteration 648: with minibatch training loss = 1.52 and accuracy of 0.64
# Iteration 649: with minibatch training loss = 1.15 and accuracy of 0.77
# Iteration 650: with minibatch training loss = 1.52 and accuracy of 0.64
# Iteration 651: with minibatch training loss = 1.43 and accuracy of 0.62
# Iteration 652: with minibatch training loss = 1.45 and accuracy of 0.62
# Iteration 653: with minibatch training loss = 1.13 and accuracy of 0.75
# Iteration 654: with minibatch training loss = 1.3 and accuracy of 0.72
# Iteration 655: with minibatch training loss = 1.23 and accuracy of 0.66
# Iteration 656: with minibatch training loss = 1.31 and accuracy of 0.66
# Iteration 657: with minibatch training loss = 1.11 and accuracy of 0.78
# Iteration 658: with minibatch training loss = 1.19 and accuracy of 0.67
# Iteration 659: with minibatch training loss = 1.51 and accuracy of 0.61
# Iteration 660: with minibatch training loss = 1.12 and accuracy of 0.73
# Iteration 661: with minibatch training loss = 1.27 and accuracy of 0.67
# Iteration 662: with minibatch training loss = 1.32 and accuracy of 0.7
# Iteration 663: with minibatch training loss = 1.2 and accuracy of 0.72
# Iteration 664: with minibatch training loss = 1.41 and accuracy of 0.64
# Iteration 665: with minibatch training loss = 1.43 and accuracy of 0.59
# Iteration 666: with minibatch training loss = 1.23 and accuracy of 0.7
# Iteration 667: with minibatch training loss = 1.05 and accuracy of 0.73
# Iteration 668: with minibatch training loss = 1.38 and accuracy of 0.69
# ...
# Iteration 20606: with minibatch training loss = 0.755 and accuracy of 0.77
# Iteration 20607: with minibatch training loss = 0.71 and accuracy of 0.75
# Iteration 20608: with minibatch training loss = 0.701 and accuracy of 0.78
# Iteration 20609: with minibatch training loss = 0.636 and accuracy of 0.78
# Iteration 20610: with minibatch training loss = 0.477 and accuracy of 0.83
# Iteration 20611: with minibatch training loss = 0.679 and accuracy of 0.78
# Iteration 20612: with minibatch training loss = 0.85 and accuracy of 0.7
# Iteration 20613: with minibatch training loss = 0.379 and accuracy of 0.92
# Iteration 20614: with minibatch training loss = 0.649 and accuracy of 0.78
# Iteration 20615: with minibatch training loss = 0.588 and accuracy of 0.83
# Iteration 20616: with minibatch training loss = 0.614 and accuracy of 0.8
# Iteration 20617: with minibatch training loss = 0.796 and accuracy of 0.73
# Iteration 20618: with minibatch training loss = 0.656 and accuracy of 0.8
# Iteration 20619: with minibatch training loss = 0.451 and accuracy of 0.83
# Iteration 20620: with minibatch training loss = 0.645 and accuracy of 0.81
# Iteration 20621: with minibatch training loss = 0.545 and accuracy of 0.83
# Iteration 20622: with minibatch training loss = 0.508 and accuracy of 0.86
# Iteration 20623: with minibatch training loss = 0.555 and accuracy of 0.8
# Iteration 20624: with minibatch training loss = 0.51 and accuracy of 0.81
# Iteration 20625: with minibatch training loss = 0.678 and accuracy of 0.75
# Iteration 20626: with minibatch training loss = 0.645 and accuracy of 0.86
# Iteration 20627: with minibatch training loss = 0.506 and accuracy of 0.83
# Iteration 20628: with minibatch training loss = 0.703 and accuracy of 0.78
# Iteration 20629: with minibatch training loss = 0.707 and accuracy of 0.77
# Iteration 20630: with minibatch training loss = 0.666 and accuracy of 0.8
# Iteration 20631: with minibatch training loss = 0.636 and accuracy of 0.8
# Iteration 20632: with minibatch training loss = 0.574 and accuracy of 0.83
# Iteration 20633: with minibatch training loss = 0.698 and accuracy of 0.8
# Iteration 20634: with minibatch training loss = 0.675 and accuracy of 0.8
# Iteration 20635: with minibatch training loss = 0.583 and accuracy of 0.81
# Iteration 20636: with minibatch training loss = 0.394 and accuracy of 0.88
# Iteration 20637: with minibatch training loss = 0.674 and accuracy of 0.77
# Iteration 20638: with minibatch training loss = 0.536 and accuracy of 0.8
# Iteration 20639: with minibatch training loss = 0.677 and accuracy of 0.77
# Iteration 20640: with minibatch training loss = 0.429 and accuracy of 0.91
# Iteration 20641: with minibatch training loss = 0.547 and accuracy of 0.83
# Iteration 20642: with minibatch training loss = 0.627 and accuracy of 0.78
# Iteration 20643: with minibatch training loss = 0.52 and accuracy of 0.83
# Iteration 20644: with minibatch training loss = 0.655 and accuracy of 0.78
# Iteration 20645: with minibatch training loss = 0.314 and accuracy of 0.91
# Iteration 20646: with minibatch training loss = 0.656 and accuracy of 0.81
# Iteration 20647: with minibatch training loss = 0.829 and accuracy of 0.78
# Iteration 20648: with minibatch training loss = 0.643 and accuracy of 0.8
# Iteration 20649: with minibatch training loss = 0.628 and accuracy of 0.78
# Iteration 20650: with minibatch training loss = 0.365 and accuracy of 0.89
# Iteration 20651: with minibatch training loss = 0.63 and accuracy of 0.8
# Iteration 20652: with minibatch training loss = 0.584 and accuracy of 0.86
# Iteration 20653: with minibatch training loss = 0.333 and accuracy of 0.88
# Iteration 20654: with minibatch training loss = 0.769 and accuracy of 0.73
# Iteration 20655: with minibatch training loss = 0.582 and accuracy of 0.83
# Iteration 20656: with minibatch training loss = 0.453 and accuracy of 0.88
# Iteration 20657: with minibatch training loss = 0.685 and accuracy of 0.77
# Iteration 20658: with minibatch training loss = 0.725 and accuracy of 0.75
# Iteration 20659: with minibatch training loss = 0.335 and accuracy of 0.89
# Iteration 20660: with minibatch training loss = 0.422 and accuracy of 0.84
# Iteration 20661: with minibatch training loss = 0.312 and accuracy of 0.89
# Iteration 20662: with minibatch training loss = 0.732 and accuracy of 0.77
# Iteration 20663: with minibatch training loss = 0.678 and accuracy of 0.75
# Iteration 20664: with minibatch training loss = 0.804 and accuracy of 0.78
# Iteration 20665: with minibatch training loss = 0.736 and accuracy of 0.73
# Iteration 20666: with minibatch training loss = 0.792 and accuracy of 0.78
# Iteration 20667: with minibatch training loss = 0.654 and accuracy of 0.8
# Iteration 20668: with minibatch training loss = 0.55 and accuracy of 0.81
# Iteration 20669: with minibatch training loss = 0.31 and accuracy of 0.92
# Iteration 20670: with minibatch training loss = 0.319 and accuracy of 0.89
# Iteration 20671: with minibatch training loss = 0.63 and accuracy of 0.81
# Iteration 20672: with minibatch training loss = 0.448 and accuracy of 0.86
# Iteration 20673: with minibatch training loss = 0.731 and accuracy of 0.8
# Iteration 20674: with minibatch training loss = 0.733 and accuracy of 0.77
# Iteration 20675: with minibatch training loss = 0.53 and accuracy of 0.83
# Iteration 20676: with minibatch training loss = 0.92 and accuracy of 0.69
# Iteration 20677: with minibatch training loss = 0.529 and accuracy of 0.84
# Iteration 20678: with minibatch training loss = 0.671 and accuracy of 0.83
# Iteration 20679: with minibatch training loss = 0.733 and accuracy of 0.75
# Iteration 20680: with minibatch training loss = 0.445 and accuracy of 0.88
# Iteration 20681: with minibatch training loss = 0.756 and accuracy of 0.75
# Iteration 20682: with minibatch training loss = 0.547 and accuracy of 0.84
# Iteration 20683: with minibatch training loss = 0.719 and accuracy of 0.77
# Iteration 20684: with minibatch training loss = 0.485 and accuracy of 0.83
# Iteration 20685: with minibatch training loss = 0.504 and accuracy of 0.88
# Iteration 20686: with minibatch training loss = 0.625 and accuracy of 0.81
# Iteration 20687: with minibatch training loss = 0.621 and accuracy of 0.78
# Iteration 20688: with minibatch training loss = 0.515 and accuracy of 0.88
# Iteration 20689: with minibatch training loss = 0.493 and accuracy of 0.83
# Iteration 20690: with minibatch training loss = 0.605 and accuracy of 0.8
# Iteration 20691: with minibatch training loss = 0.887 and accuracy of 0.69
# Iteration 20692: with minibatch training loss = 0.585 and accuracy of 0.81
# Iteration 20693: with minibatch training loss = 0.515 and accuracy of 0.81
# Iteration 20694: with minibatch training loss = 0.662 and accuracy of 0.78
# Iteration 20695: with minibatch training loss = 0.525 and accuracy of 0.8
# Iteration 20696: with minibatch training loss = 0.557 and accuracy of 0.84
# Iteration 20697: with minibatch training loss = 0.628 and accuracy of 0.78
# Iteration 20698: with minibatch training loss = 0.591 and accuracy of 0.78
# Iteration 20699: with minibatch training loss = 0.638 and accuracy of 0.83
# Iteration 20700: with minibatch training loss = 0.87 and accuracy of 0.72
# Iteration 20701: with minibatch training loss = 0.527 and accuracy of 0.83
# Iteration 20702: with minibatch training loss = 0.852 and accuracy of 0.77
# Iteration 20703: with minibatch training loss = 0.504 and accuracy of 0.84
# Iteration 20704: with minibatch training loss = 0.698 and accuracy of 0.75
# Iteration 20705: with minibatch training loss = 0.684 and accuracy of 0.77
# Iteration 20706: with minibatch training loss = 0.511 and accuracy of 0.8
# Iteration 20707: with minibatch training loss = 0.67 and accuracy of 0.8
# Iteration 20708: with minibatch training loss = 0.423 and accuracy of 0.88
# Iteration 20709: with minibatch training loss = 0.471 and accuracy of 0.84
# Iteration 20710: with minibatch training loss = 0.729 and accuracy of 0.77
# Iteration 20711: with minibatch training loss = 0.433 and accuracy of 0.83
# Iteration 20712: with minibatch training loss = 0.676 and accuracy of 0.78
# Iteration 20713: with minibatch training loss = 0.697 and accuracy of 0.78
# Iteration 20714: with minibatch training loss = 0.639 and accuracy of 0.8
# Iteration 20715: with minibatch training loss = 0.643 and accuracy of 0.86
# Iteration 20716: with minibatch training loss = 0.373 and accuracy of 0.91
# Iteration 20717: with minibatch training loss = 0.573 and accuracy of 0.81
# Iteration 20718: with minibatch training loss = 0.372 and accuracy of 0.88
# Iteration 20719: with minibatch training loss = 0.45 and accuracy of 0.86
# Iteration 20720: with minibatch training loss = 0.793 and accuracy of 0.77
# Iteration 20721: with minibatch training loss = 0.566 and accuracy of 0.83
# Iteration 20722: with minibatch training loss = 0.769 and accuracy of 0.8
# Iteration 20723: with minibatch training loss = 0.629 and accuracy of 0.81
# Iteration 20724: with minibatch training loss = 0.751 and accuracy of 0.8
# Iteration 20725: with minibatch training loss = 0.601 and accuracy of 0.8
# Iteration 20726: with minibatch training loss = 0.371 and accuracy of 0.94
# Iteration 20727: with minibatch training loss = 0.62 and accuracy of 0.83
# Iteration 20728: with minibatch training loss = 0.644 and accuracy of 0.78
# Iteration 20729: with minibatch training loss = 0.547 and accuracy of 0.83
# Iteration 20730: with minibatch training loss = 0.655 and accuracy of 0.81
# Iteration 20731: with minibatch training loss = 0.718 and accuracy of 0.77
# Iteration 20732: with minibatch training loss = 0.46 and accuracy of 0.86
# Iteration 20733: with minibatch training loss = 0.538 and accuracy of 0.84
# Iteration 20734: with minibatch training loss = 0.604 and accuracy of 0.84
# Iteration 20735: with minibatch training loss = 0.565 and accuracy of 0.8
# Iteration 20736: with minibatch training loss = 0.715 and accuracy of 0.8
# Iteration 20737: with minibatch training loss = 0.726 and accuracy of 0.75
# Iteration 20738: with minibatch training loss = 0.741 and accuracy of 0.75
# Iteration 20739: with minibatch training loss = 0.473 and accuracy of 0.86
# Iteration 20740: with minibatch training loss = 0.779 and accuracy of 0.72
# Iteration 20741: with minibatch training loss = 0.735 and accuracy of 0.78
# Iteration 20742: with minibatch training loss = 0.67 and accuracy of 0.78
# Iteration 20743: with minibatch training loss = 0.712 and accuracy of 0.73
# Iteration 20744: with minibatch training loss = 0.506 and accuracy of 0.81
# Iteration 20745: with minibatch training loss = 0.968 and accuracy of 0.64
# Iteration 20746: with minibatch training loss = 0.637 and accuracy of 0.78
# Iteration 20747: with minibatch training loss = 0.682 and accuracy of 0.77
# Iteration 20748: with minibatch training loss = 0.597 and accuracy of 0.81
# Iteration 20749: with minibatch training loss = 0.547 and accuracy of 0.83
# Iteration 20750: with minibatch training loss = 0.501 and accuracy of 0.86
# Iteration 20751: with minibatch training loss = 0.679 and accuracy of 0.8
# Iteration 20752: with minibatch training loss = 0.591 and accuracy of 0.81
# Iteration 20753: with minibatch training loss = 0.479 and accuracy of 0.84
# Iteration 20754: with minibatch training loss = 0.507 and accuracy of 0.88
# Iteration 20755: with minibatch training loss = 0.779 and accuracy of 0.75
# Iteration 20756: with minibatch training loss = 0.872 and accuracy of 0.73
# Iteration 20757: with minibatch training loss = 0.623 and accuracy of 0.77
# Iteration 20758: with minibatch training loss = 0.519 and accuracy of 0.81
# Iteration 20759: with minibatch training loss = 0.647 and accuracy of 0.75
# Iteration 20760: with minibatch training loss = 0.808 and accuracy of 0.73
# Iteration 20761: with minibatch training loss = 0.558 and accuracy of 0.83
# Iteration 20762: with minibatch training loss = 0.579 and accuracy of 0.83
# Iteration 20763: with minibatch training loss = 0.658 and accuracy of 0.78
# Iteration 20764: with minibatch training loss = 0.738 and accuracy of 0.77
# Iteration 20765: with minibatch training loss = 0.596 and accuracy of 0.84
# Iteration 20766: with minibatch training loss = 0.611 and accuracy of 0.83
# Iteration 20767: with minibatch training loss = 0.641 and accuracy of 0.78
# Iteration 20768: with minibatch training loss = 0.7 and accuracy of 0.78
# Iteration 20769: with minibatch training loss = 0.505 and accuracy of 0.83
# Iteration 20770: with minibatch training loss = 0.766 and accuracy of 0.75
# Iteration 20771: with minibatch training loss = 0.741 and accuracy of 0.78
# Iteration 20772: with minibatch training loss = 0.621 and accuracy of 0.8
# Iteration 20773: with minibatch training loss = 0.791 and accuracy of 0.7
# Iteration 20774: with minibatch training loss = 0.586 and accuracy of 0.84
# Iteration 20775: with minibatch training loss = 0.452 and accuracy of 0.86
# Iteration 20776: with minibatch training loss = 0.696 and accuracy of 0.8
# Iteration 20777: with minibatch training loss = 0.546 and accuracy of 0.78
# Iteration 20778: with minibatch training loss = 0.559 and accuracy of 0.81
# Iteration 20779: with minibatch training loss = 0.584 and accuracy of 0.83
# Iteration 20780: with minibatch training loss = 0.661 and accuracy of 0.8
# Iteration 20781: with minibatch training loss = 0.663 and accuracy of 0.77
# Iteration 20782: with minibatch training loss = 0.463 and accuracy of 0.86
# Iteration 20783: with minibatch training loss = 0.516 and accuracy of 0.81
# Iteration 20784: with minibatch training loss = 0.769 and accuracy of 0.77
# Iteration 20785: with minibatch training loss = 0.559 and accuracy of 0.81
# Iteration 20786: with minibatch training loss = 0.351 and accuracy of 0.89
# Iteration 20787: with minibatch training loss = 0.793 and accuracy of 0.72
# Iteration 20788: with minibatch training loss = 0.694 and accuracy of 0.81
# Iteration 20789: with minibatch training loss = 0.55 and accuracy of 0.83
# Iteration 20790: with minibatch training loss = 0.587 and accuracy of 0.8
# Iteration 20791: with minibatch training loss = 0.429 and accuracy of 0.88
# Iteration 20792: with minibatch training loss = 0.733 and accuracy of 0.77
# Iteration 20793: with minibatch training loss = 0.582 and accuracy of 0.84
# Iteration 20794: with minibatch training loss = 0.55 and accuracy of 0.81
# Iteration 20795: with minibatch training loss = 0.524 and accuracy of 0.88
# Iteration 20796: with minibatch training loss = 0.583 and accuracy of 0.83
# Iteration 20797: with minibatch training loss = 0.764 and accuracy of 0.72
# Iteration 20798: with minibatch training loss = 0.579 and accuracy of 0.8
# Iteration 20799: with minibatch training loss = 0.681 and accuracy of 0.78
# Iteration 20800: with minibatch training loss = 0.47 and accuracy of 0.81
# Iteration 20801: with minibatch training loss = 0.71 and accuracy of 0.77
# Iteration 20802: with minibatch training loss = 0.779 and accuracy of 0.72
# Iteration 20803: with minibatch training loss = 0.394 and accuracy of 0.89
# Iteration 20804: with minibatch training loss = 0.621 and accuracy of 0.75
# Iteration 20805: with minibatch training loss = 0.76 and accuracy of 0.7
# Iteration 20806: with minibatch training loss = 0.65 and accuracy of 0.83
# Iteration 20807: with minibatch training loss = 0.499 and accuracy of 0.86
# Iteration 20808: with minibatch training loss = 0.611 and accuracy of 0.8
# Iteration 20809: with minibatch training loss = 0.828 and accuracy of 0.78
# Iteration 20810: with minibatch training loss = 0.505 and accuracy of 0.86
# Iteration 20811: with minibatch training loss = 0.527 and accuracy of 0.86
# Iteration 20812: with minibatch training loss = 0.55 and accuracy of 0.84
# Iteration 20813: with minibatch training loss = 0.641 and accuracy of 0.8
# Iteration 20814: with minibatch training loss = 0.665 and accuracy of 0.78
# Iteration 20815: with minibatch training loss = 0.734 and accuracy of 0.75
# Iteration 20816: with minibatch training loss = 0.612 and accuracy of 0.81
# Iteration 20817: with minibatch training loss = 0.716 and accuracy of 0.8
# Iteration 20818: with minibatch training loss = 0.683 and accuracy of 0.8
# Validation loss: 0.22378348
# Epoch 15, Overall loss = 0.604 and accuracy of 0.806

# %%
# Test model:
print(model.evaluate(X_test, y_test_enc))
# Out:
# Validation loss: 0.18566152
# Epoch 1, Overall loss = 0.334 and accuracy of 0.914
# None
